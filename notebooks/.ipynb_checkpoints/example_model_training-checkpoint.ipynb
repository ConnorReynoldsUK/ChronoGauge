# %% [markdown]
# # Using pre-defined features & parameters to train a time prediction model
# Here we will demonstrate how to train a sub-predictor with features identified using sequential feature selection and hyperparameters determined using 5-fold cross-validation

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
import pickle
import math
import random
import os
from chronogauge_model import model_nn, utils

# %%
# Define seed
SEED = 0
random.seed(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)
os.environ['PYTHONHASHSEED'] = str(SEED)

# %% [markdown]
# ## 1. Data loading and pre-processing
# First we load the training data

# %%
# Load the training samples' expresion matrix
X_train = pd.read_csv('../data/expression_matrices/x_training.csv', index_col=0)

# Load the training samples' targets
Y_train = pd.read_csv('../data/targets/target_training.csv', index_col=0)

# %% [markdown]
# The model takes only sine and cosine values of the 24-hour sampling time as an input. This converts the target into sine(time) and -cosine(time)

# %%
def cyclic_time(times):
    #this is used to convert the target (time of sampling) in hours to cosine and sine values
    times = times % 24
    t_cos = -np.cos((2 * np.pi * times.astype('float64') / 24)+(np.pi/2))
    t_sin = np.sin((2 * np.pi * times.astype('float64') / 24)+(np.pi/2))
    
    t_circular = np.concatenate((np.asarray(t_cos).reshape(-1, 1), np.asarray(t_sin).reshape(-1, 1)), axis=1)

    return t_circular

# %%
# Convert Y_test targets into sine and cosine values for each sample
Y_data = cyclic_time(Y_train.iloc[:,0])

# %% [markdown]
# Now we load the test data and make sure it's features correspond with the training and is z-score scaled with reference to the training's scaling factor

# %%
# load the test samples' expression matrix
X_test = pd.read_csv('../data/expression_matrices/x_test_rna.csv', index_col=0)

# Load the test sample's target sampling times that were are trying to predict
Y_test = pd.read_csv('../data/targets/target_test_rna.csv', index_col=0)

# Ensure test has same feature space as training
X_test = X_test.loc[X_train.index]

# Standardize the training expression values using z-score scaling (StandardScaler)
scaler = StandardScaler()
X_train = pd.DataFrame(data=scaler.fit_transform(X_train.T).T, index=X_train.index, columns=X_train.columns)


# Fit the test data to scaling factor of the training
X_test = pd.DataFrame(data=scaler.transform(X_test.T).T, index=X_test.index, columns=X_test.columns)

# %% [markdown]
# __NOTE__ if using microarray data, the test data should be standardized using a scaling factor that has been fit to a microrray time-course, not an RNA-seq experiment.

# %% [markdown]
# ## 2. Model training
# In this instance, we will use features and hyperparameters that have been pre-determined for model id 0

# %% [markdown]
# The model can theoretically be fit to any of the features found in the training expression matrix, but we recommend either using our ensemble of features or the 17 cannonical circadian clock genes, as these have been validated

# %%
# load features for model id 0
features = pd.read_csv('../data/model_parameters/gene_features_unadjusted.csv', index_col=0)
features = features.iloc[0].dropna().to_numpy()

# Cannonical clock genes in case users wish to use them instead
# clock_genes = ['AT5G61380', 'AT2G46830', 'AT1G01060', 'AT5G02810', 'AT2G46790', 'AT2G25930', 'AT1G22770', 'AT5G42900',
#       'AT3G46640','AT5G59570', 'AT5G60100', 'AT3G22380', 'AT4G39620', 'AT5G57360', 'AT2G31870',  'AT2G21070',
#       'AT3G20810']

# Select only these features for training and test data
X_train = X_train.loc[features]
X_test = X_test.loc[features]

# load model hyperparameters for model id 0
with open('../data/model_parameters/model_parameters.p', 'rb') as fin:
    hyperparams = pickle.load(fin)
hyperparams = hyperparams[0]

# Extract specific hyperparameters including learning rate and batch size
lr = float(hyperparams['lr'])
batches = int(hyperparams['batches'])
l2 = lr

# %% [markdown]
# __NOTE__ during model tuning for each sub-predictor, the learning rate was mistakenly also set for l2 regululrization factor. Although there is no theoretical reason to expect these two hyperparameters to have the same value, this configuration was empirically found to perform optimally based on 5-fold cross-validation. The model's performance under these settings was deemed acceptable and considered optimal for CT prediction.

# %% [markdown]
# We call the neural network model from model_nn.py using the aforementioned hyperparameters

# %%
model = model_nn.MultiOutputNN(learning_rate=lr,l2_reg=l2, batch_size=batches).nn_model()

# %% [markdown]
# The model was optimized using an EarlyStop function to restore the weights of the epoch giving the smallest loss

# %%
early_stop = EarlyStopping(patience=25, restore_best_weights=True, monitor='loss', mode='min')

# %% [markdown]
# We fit the neural network to the training data. Depending on the feature set and hyperparmeters used, this may take time.

# %%
model.fit(X_train.astype('float32').T, Y_data.astype('float32'), epochs=5000, verbose=1, callbacks=[early_stop])
# Out:
# Epoch 1/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 1.7051
# Epoch 2/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.6525
# Epoch 3/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.6134
# Epoch 4/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.5800
# Epoch 5/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.5496
# Epoch 6/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.5223
# Epoch 7/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.4948
# Epoch 8/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.4648
# Epoch 9/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.4325
# Epoch 10/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3988
# Epoch 11/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3624
# Epoch 12/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3250
# Epoch 13/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.2876
# Epoch 14/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.2502
# Epoch 15/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.2151
# Epoch 16/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.1864
# Epoch 17/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.1546
# Epoch 18/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1219
# Epoch 19/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0858
# Epoch 20/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.0487
# Epoch 21/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0079
# Epoch 22/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.9620
# Epoch 23/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9129
# Epoch 24/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.8684
# Epoch 25/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.8283
# Epoch 26/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7924
# Epoch 27/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.7642
# Epoch 28/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.7340
# Epoch 29/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.6983
# Epoch 30/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6673
# Epoch 31/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.6375
# Epoch 32/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.6095
# Epoch 33/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5832
# Epoch 34/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5568
# Epoch 35/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5302
# Epoch 36/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5051
# Epoch 37/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4875
# Epoch 38/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4725
# Epoch 39/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4564
# Epoch 40/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4385
# Epoch 41/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4203
# Epoch 42/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4052
# Epoch 43/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3916
# Epoch 44/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3804
# Epoch 45/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3679
# Epoch 46/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3561
# Epoch 47/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3440
# Epoch 48/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3329
# Epoch 49/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3229
# Epoch 50/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3148
# Epoch 51/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3072
# Epoch 52/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2980
# Epoch 53/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2886
# Epoch 54/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2795
# Epoch 55/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2731
# Epoch 56/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2672
# Epoch 57/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2615
# Epoch 58/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2555
# Epoch 59/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2492
# Epoch 60/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2427
# Epoch 61/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2365
# Epoch 62/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2305
# Epoch 63/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2251
# Epoch 64/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2197
# Epoch 65/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2154
# Epoch 66/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2103
# Epoch 67/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2054
# Epoch 68/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1991
# Epoch 69/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1951
# Epoch 70/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1904
# Epoch 71/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1853
# Epoch 72/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1799
# Epoch 73/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1767
# Epoch 74/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1723
# Epoch 75/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1681
# Epoch 76/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1634
# Epoch 77/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1606
# Epoch 78/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1574
# Epoch 79/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1536
# Epoch 80/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1482
# Epoch 81/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1505
# Epoch 82/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1458
# Epoch 83/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1427
# Epoch 84/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1398
# Epoch 85/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1383
# Epoch 86/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1355
# Epoch 87/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1317
# Epoch 88/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1307
# Epoch 89/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1269
# Epoch 90/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1260
# Epoch 91/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1241
# Epoch 92/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1212
# Epoch 93/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1185
# Epoch 94/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1163
# Epoch 95/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1137
# Epoch 96/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1118
# Epoch 97/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1102
# Epoch 98/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1080
# Epoch 99/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1053
# Epoch 100/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1020
# Epoch 101/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0996
# Epoch 102/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0989
# Epoch 103/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1005
# Epoch 104/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0948
# Epoch 105/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0936
# Epoch 106/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0902
# Epoch 107/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0893
# Epoch 108/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0889
# Epoch 109/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0872
# Epoch 110/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0832
# Epoch 111/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0874
# Epoch 112/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0842
# Epoch 113/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0816
# Epoch 114/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0786
# Epoch 115/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0766
# Epoch 116/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0781
# Epoch 117/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0705
# Epoch 118/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0743
# Epoch 119/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0698
# Epoch 120/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0664
# Epoch 121/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0642
# Epoch 122/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0636
# Epoch 123/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0585
# Epoch 124/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0616
# Epoch 125/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0585
# Epoch 126/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0540
# Epoch 127/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0528
# Epoch 128/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0557
# Epoch 129/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0516
# Epoch 130/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0543
# Epoch 131/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0525
# Epoch 132/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0523
# Epoch 133/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0484
# Epoch 134/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0501
# Epoch 135/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0480
# Epoch 136/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0472
# Epoch 137/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0464
# Epoch 138/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0463
# Epoch 139/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0458
# Epoch 140/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0449
# Epoch 141/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0434
# Epoch 142/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0435
# Epoch 143/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0427
# Epoch 144/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0423
# Epoch 145/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0413
# Epoch 146/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0409
# Epoch 147/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0411
# Epoch 148/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0392
# Epoch 149/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0390
# Epoch 150/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0372
# Epoch 151/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0382
# Epoch 152/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0373
# Epoch 153/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0373
# Epoch 154/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0358
# Epoch 155/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0373
# Epoch 156/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0363
# Epoch 157/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0351
# Epoch 158/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0338
# Epoch 159/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0337
# Epoch 160/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0344
# Epoch 161/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0335
# Epoch 162/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0324
# Epoch 163/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0323
# Epoch 164/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0316
# Epoch 165/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0311
# Epoch 166/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0308
# Epoch 167/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0313
# Epoch 168/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0307
# Epoch 169/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0302
# Epoch 170/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0296
# Epoch 171/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0297
# Epoch 172/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0297
# Epoch 173/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0292
# Epoch 174/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0289
# Epoch 175/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0287
# Epoch 176/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0284
# Epoch 177/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0281
# Epoch 178/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0275
# Epoch 179/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0275
# Epoch 180/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0271
# Epoch 181/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0273
# Epoch 182/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0267
# Epoch 183/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0266
# Epoch 184/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0262
# Epoch 185/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0260
# Epoch 186/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0260
# Epoch 187/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0258
# Epoch 188/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0260
# Epoch 189/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0255
# Epoch 190/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0257
# Epoch 191/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0252
# Epoch 192/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0251
# Epoch 193/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0250
# Epoch 194/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0248
# Epoch 195/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0248
# Epoch 196/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0247
# Epoch 197/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0245
# Epoch 198/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0244
# Epoch 199/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0243
# Epoch 200/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0243
# Epoch 201/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0241
# Epoch 202/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0243
# Epoch 203/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0241
# Epoch 204/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0242
# Epoch 205/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0240
# Epoch 206/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0240
# Epoch 207/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0237
# Epoch 208/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0238
# Epoch 209/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0237
# Epoch 210/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0237
# Epoch 211/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0235
# Epoch 212/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0236
# Epoch 213/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0234
# Epoch 214/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0235
# Epoch 215/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0232
# Epoch 216/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0233
# Epoch 217/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0231
# Epoch 218/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0232
# Epoch 219/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0230
# Epoch 220/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0230
# Epoch 221/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0228
# Epoch 222/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0229
# Epoch 223/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0227
# Epoch 224/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0227
# Epoch 225/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0226
# Epoch 226/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0226
# Epoch 227/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0224
# Epoch 228/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0225
# Epoch 229/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0223
# Epoch 230/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0223
# Epoch 231/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0222
# Epoch 232/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0222
# Epoch 233/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0220
# Epoch 234/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0221
# Epoch 235/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0219
# Epoch 236/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0220
# Epoch 237/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0218
# Epoch 238/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0219
# Epoch 239/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0217
# Epoch 240/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0218
# Epoch 241/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0216
# Epoch 242/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0216
# Epoch 243/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0214
# Epoch 244/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0215
# Epoch 245/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0213
# Epoch 246/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0214
# Epoch 247/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0212
# Epoch 248/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0213
# Epoch 249/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0211
# Epoch 250/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0211
# Epoch 251/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0210
# Epoch 252/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0210
# Epoch 253/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0208
# Epoch 254/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0209
# Epoch 255/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0207
# Epoch 256/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0208
# Epoch 257/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0206
# Epoch 258/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0207
# Epoch 259/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0205
# Epoch 260/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0206
# Epoch 261/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0204
# Epoch 262/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0205
# Epoch 263/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0203
# Epoch 264/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0204
# Epoch 265/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0203
# Epoch 266/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0204
# Epoch 267/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0203
# Epoch 268/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0204
# Epoch 269/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0202
# Epoch 270/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0203
# Epoch 271/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0201
# Epoch 272/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0202
# Epoch 273/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0201
# Epoch 274/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0202
# Epoch 275/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0201
# Epoch 276/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0202
# Epoch 277/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0200
# Epoch 278/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0201
# Epoch 279/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0200
# Epoch 280/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0201
# Epoch 281/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0199
# Epoch 282/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0200
# Epoch 283/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0199
# Epoch 284/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0200
# Epoch 285/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0198
# Epoch 286/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0199
# Epoch 287/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0198
# Epoch 288/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0199
# Epoch 289/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0197
# Epoch 290/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0198
# Epoch 291/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0197
# Epoch 292/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0198
# Epoch 293/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0197
# Epoch 294/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0197
# Epoch 295/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0196
# Epoch 296/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0197
# Epoch 297/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0196
# Epoch 298/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0197
# Epoch 299/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0195
# Epoch 300/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0196
# Epoch 301/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0195
# Epoch 302/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0196
# Epoch 303/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0194
# Epoch 304/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0195
# Epoch 305/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0194
# Epoch 306/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0195
# Epoch 307/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0193
# Epoch 308/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0194
# Epoch 309/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0193
# Epoch 310/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0194
# Epoch 311/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0192
# Epoch 312/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0193
# Epoch 313/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0192
# Epoch 314/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0193
# Epoch 315/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0192
# Epoch 316/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0192
# Epoch 317/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0191
# Epoch 318/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0192
# Epoch 319/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0190
# Epoch 320/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0192
# Epoch 321/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0190
# Epoch 322/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0191
# Epoch 323/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0190
# Epoch 324/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0191
# Epoch 325/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0189
# Epoch 326/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0190
# Epoch 327/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0189
# Epoch 328/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0189
# Epoch 329/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0188
# Epoch 330/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0189
# Epoch 331/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0188
# Epoch 332/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0188
# Epoch 333/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0187
# Epoch 334/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0188
# Epoch 335/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0186
# Epoch 336/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0187
# Epoch 337/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0186
# Epoch 338/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0187
# Epoch 339/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0185
# Epoch 340/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0186
# Epoch 341/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0185
# Epoch 342/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0186
# Epoch 343/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0185
# Epoch 344/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0186
# Epoch 345/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0184
# Epoch 346/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0185
# Epoch 347/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0183
# Epoch 348/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0184
# Epoch 349/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0183
# Epoch 350/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0184
# Epoch 351/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0182
# Epoch 352/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0183
# Epoch 353/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0182
# Epoch 354/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0183
# Epoch 355/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0181
# Epoch 356/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0182
# Epoch 357/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0181
# Epoch 358/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0181
# Epoch 359/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0180
# Epoch 360/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0181
# Epoch 361/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0179
# Epoch 362/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0180
# Epoch 363/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0179
# Epoch 364/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0180
# Epoch 365/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0178
# Epoch 366/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0179
# Epoch 367/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0178
# Epoch 368/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0179
# Epoch 369/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0177
# Epoch 370/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0178
# Epoch 371/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0176
# Epoch 372/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0177
# Epoch 373/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0176
# Epoch 374/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0177
# Epoch 375/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0175
# Epoch 376/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0176
# Epoch 377/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0175
# Epoch 378/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0176
# Epoch 379/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0174
# Epoch 380/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0175
# Epoch 381/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0173
# Epoch 382/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0174
# Epoch 383/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0173
# Epoch 384/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0174
# Epoch 385/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0172
# Epoch 386/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0173
# Epoch 387/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0171
# Epoch 388/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0172
# Epoch 389/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0171
# Epoch 390/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0172
# Epoch 391/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0170
# Epoch 392/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0171
# Epoch 393/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0169
# Epoch 394/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0170
# Epoch 395/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0169
# Epoch 396/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0170
# Epoch 397/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0168
# Epoch 398/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0169
# Epoch 399/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0167
# Epoch 400/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0168
# Epoch 401/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0167
# Epoch 402/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0167
# Epoch 403/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0166
# Epoch 404/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0167
# Epoch 405/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0165
# Epoch 406/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0166
# Epoch 407/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0164
# Epoch 408/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0165
# Epoch 409/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0164
# Epoch 410/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0164
# Epoch 411/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0163
# Epoch 412/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0163
# Epoch 413/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0162
# Epoch 414/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0162
# Epoch 415/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0161
# Epoch 416/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0161
# Epoch 417/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0160
# Epoch 418/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0160
# Epoch 419/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0159
# Epoch 420/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0159
# Epoch 421/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0158
# Epoch 422/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0159
# Epoch 423/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0157
# Epoch 424/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0158
# Epoch 425/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0156
# Epoch 426/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0156
# Epoch 427/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0155
# Epoch 428/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0155
# Epoch 429/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0154
# Epoch 430/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0154
# Epoch 431/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0153
# Epoch 432/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0153
# Epoch 433/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0151
# Epoch 434/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0151
# Epoch 435/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0150
# Epoch 436/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0150
# Epoch 437/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0149
# Epoch 438/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0149
# Epoch 439/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0148
# Epoch 440/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0148
# Epoch 441/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0147
# Epoch 442/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0147
# Epoch 443/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0146
# Epoch 444/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0146
# Epoch 445/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0145
# Epoch 446/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0145
# Epoch 447/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0143
# Epoch 448/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0143
# Epoch 449/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0142
# Epoch 450/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0142
# Epoch 451/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0141
# Epoch 452/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0141
# Epoch 453/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0139
# Epoch 454/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0139
# Epoch 455/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0138
# Epoch 456/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0138
# Epoch 457/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0137
# Epoch 458/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0137
# Epoch 459/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0135
# Epoch 460/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0135
# Epoch 461/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0134
# Epoch 462/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0134
# Epoch 463/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0133
# Epoch 464/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0133
# Epoch 465/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0131
# Epoch 466/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0131
# Epoch 467/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0130
# Epoch 468/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0130
# Epoch 469/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0128
# Epoch 470/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0128
# Epoch 471/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0127
# Epoch 472/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0127
# Epoch 473/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0125
# Epoch 474/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0125
# Epoch 475/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0124
# Epoch 476/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0124
# Epoch 477/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0122
# Epoch 478/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0122
# Epoch 479/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0121
# Epoch 480/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0120
# Epoch 481/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0119
# Epoch 482/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0119
# Epoch 483/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0117
# Epoch 484/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0117
# Epoch 485/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0116
# Epoch 486/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0116
# Epoch 487/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0114
# Epoch 488/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0114
# Epoch 489/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0112
# Epoch 490/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0112
# Epoch 491/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0110
# Epoch 492/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0110
# Epoch 493/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0108
# Epoch 494/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0108
# Epoch 495/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0107
# Epoch 496/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0106
# Epoch 497/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0105
# Epoch 498/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0104
# Epoch 499/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0103
# Epoch 500/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0102
# Epoch 501/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0101
# Epoch 502/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0100
# Epoch 503/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0099
# Epoch 504/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0098
# Epoch 505/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0097
# Epoch 506/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0096
# Epoch 507/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0094
# Epoch 508/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0094
# Epoch 509/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0092
# Epoch 510/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0092
# Epoch 511/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0090
# Epoch 512/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0090
# Epoch 513/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0088
# Epoch 514/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0087
# Epoch 515/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0086
# Epoch 516/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0085
# Epoch 517/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0083
# Epoch 518/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0083
# Epoch 519/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0083
# Epoch 520/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0082
# Epoch 521/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0082
# Epoch 522/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0083
# Epoch 523/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0084
# Epoch 524/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0084
# Epoch 525/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0084
# Epoch 526/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0084
# Epoch 527/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0085
# Epoch 528/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0084
# Epoch 529/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0085
# Epoch 530/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0084
# Epoch 531/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0085
# Epoch 532/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0084
# Epoch 533/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0084
# Epoch 534/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0084
# Epoch 535/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0084
# Epoch 536/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0084
# Epoch 537/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0084
# Epoch 538/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0084
# Epoch 539/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0084
# Epoch 540/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0084
# Epoch 541/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0084
# Epoch 542/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0084
# Epoch 543/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0084
# Epoch 544/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0084
# Epoch 545/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0084
# Epoch 546/5000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0084

# %% [markdown]
# We can save this specific model so we can use it again. It is a good idea to record the features used, as these will be required when loading and running the model in future.

# %%
model.save('
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# array([[ 1.6396092e-03,  2.5326002e-02],
#        [-3.2094736e-03,  2.5695318e-02],
#        [-5.2083092e-04,  1.0002324e-02],
#        [-1.0408386e-02,  9.3809757e-03],
#        [-1.0003201e-02,  1.0912423e-02],
#        [-7.3061259e-03,  2.4408862e-02],
#        [-2.9632188e-03,  1.9786457e-02],
#        [ 2.7690802e-03,  1.1810710e-02],
#        [-6.9589954e-04,  4.4697067e-03],
#        [-1.2861886e-02, -1.1332051e-03],
#        [-9.0144072e-03,  1.0421447e-02],
#        [-8.1061544e-03,  1.3787812e-02],
#        [ 1.4288819e-03, -1.4312568e-02],
#        [ 1.0324783e-02, -1.3836695e-02],
#        [-4.9434444e-03, -1.0504469e-03],
#        [ 1.9424232e-03, -1.7619613e-03],
#        [-9.2764635e-04,  3.0543166e-03],
#        [ 6.9316356e-03, -6.1345496e-04],
#        [-2.8327762e-05,  8.2057547e-03],
#        [-8.0880076e-03,  5.2644294e-03],
#        [-4.2485603e-04,  2.2550423e-03],
#        [-9.2012798e-03,  1.1589740e-02],
#        [-1.3207435e-02,  1.6234607e-02],
#        [-7.7928007e-03,  1.7937686e-02],
#        [ 2.3911232e-02,  4.0209247e-03],
#        [ 2.6469439e-02,  1.0277942e-02],
#        [ 1.7268188e-02,  5.4255640e-03],
#        [-2.3509804e-03, -6.6468660e-03],
#        [ 3.2029308e-02, -1.3598023e-02],
#        [ 6.2494883e-03, -1.2100108e-02],
#        [ 1.5200331e-02,  7.9305843e-03],
#        [ 1.3320809e-03, -6.4302571e-03],
#        [ 1.4774968e-02, -6.2700617e-04],
#        [ 4.9295407e-03, -5.6013763e-03],
#        [-2.0524761e-02,  5.5106776e-03],
#        [-1.8597491e-02,  4.3915454e-03],
#        [-1.3289150e-02,  1.0520317e-02],
#        [-4.4058273e-03,  5.9773205e-03],
#        [ 2.6166970e-03, -7.0307869e-03],
#        [ 9.3270158e-03, -6.4154994e-03],
#        [-2.3606927e-04,  2.6463822e-02],
#        [ 9.4608581e-03,  2.6070032e-02],
#        [-3.9111711e-03,  2.0318151e-02],
#        [-6.7127211e-04, -8.3826529e-03],
#        [-1.0677078e-03, -6.8230610e-03],
#        [-7.9472093e-03, -1.6756987e-03],
#        [ 1.1903162e-02, -4.7697090e-03],
#        [ 1.2786058e-02, -5.9381779e-03],
#        [ 6.7137079e-03, -3.4678890e-04],
#        [-1.1915314e-02,  8.4486441e-04],
#        [ 8.3454065e-03,  4.8293527e-03],
#        [ 1.2683285e-02, -8.1919748e-03],
#        [-1.5496717e-02,  3.4493212e-02],
#        [-1.2828360e-02,  2.4405956e-02],
#        [ 6.0772109e-03, -3.4398071e-03],
#        [-1.3476085e-02,  3.3473115e-02],
#        [ 5.9331098e-04, -6.2602414e-03],
#        [ 1.1231381e-02, -7.9480866e-03]], dtype=float32)

# %% [markdown]
# ## 2. Applying models
# Using the gene features correspoding to each model (based on id), we can predict the CT.

# %% [markdown]
# Example with model 0:

# %%
# extract id 0 model & features from model dictionary
model_0, features_0 = model_dict[0]



# X_test must use only id 0's features
X_test_0 = X_test.loc[features_0]

#predict CT of the test data
results_0 = model_0(X_test_0.T)
results_0[:10]

# %% [markdown]
# Example with models 0-9:

# %%
results_dict = {}
# Iterate over model ids and predict
for i in range(0, 10):
    i_model, i_features = model_dict[i]
    # Set test features
    i_X_test = X_test.loc[i_features]
    i_results = i_model(i_X_test.T)
    results_dict[i] = i_results
np.asarray(results_dict[9])[:10]

# %% [markdown]
# ## 3. Processing results of individual sub-predictors
# The model generates two outputs - circular values representing the sin(CT) and -cos(CT). Thus, they must be converted back into an hourly CT value using the following atan function (note this is included in utils.py):

# %%
def time24(ipreds):
    #returns times as an hourly value within a 24-hour modulus
    preds = []
    for i in range(ipreds.shape[0]):
        preds.append(math.atan2(ipreds[i, 0], ipreds[i, 1]) / math.pi * 12)

    for i in range(len(preds)):
        if preds[i] < 0:
            preds[i] = preds[i] + 24
    return preds

# %%
pred24_0 = time24(results_dict[0])
pred24_0[:10]

# %% [markdown]
# The errors of individual sub-predictors can be analyzed using the following function considering 24 hours as a modulus:

# %%
def errors(pred, true):
    # Ensure 24-hour modulus in the target
    true = true % 24
    #from 24-hour time predictions, get error in minutes
    err = pred - true
    for i in range(0, err.shape[0]):
        if err.iloc[i] > 12:
            err.iloc[i] = err.iloc[i] - 24
        if err.iloc[i] < -12:
            err.iloc[i] = err.iloc[i] + 24
    # return error in minutes
    return err*60

# %%
error_0 = errors(pred24_0, Y_test.iloc[:,0])
error_0.head()

# %% [markdown]
# However, based on cross-validation results, we found individual sub-predictors are unreliable and it is impossible to tell which sub-predictors will peform accurately or innacurately in unseen test samples.

# %% [markdown]
# ## 4. Aggretation of results of individual sub-predictors
# To overcome this unreliability, we aggregate sub-predictor outputs using a circular mean. Combining predictions as a bagging-like ensemble is essential to ChronoGauge's consistent performance across unseen data.

# %% [markdown]
# The following function converts 24-hour CT predictions into sine/cosine values

# %%
def cyclic_time(times):
    #this is used to convert the target (time of sampling) in hours to cosine and sine values
    times = times % 24
    t_cos = -np.cos((2 * np.pi * times.astype('float64') / 24)+(np.pi/2))
    t_sin = np.sin((2 * np.pi * times.astype('float64') / 24)+(np.pi/2))
    
    return t_cos, t_sin

# %% [markdown]
# The following function uses cyclic_time() to aggregate the results of a dataframe of 24-hour CT predictions

# %%
def circular_mean(predictions_24):
    cos_vals = []
    sin_vals = []

    for i in range(0, predictions_24.shape[1]):
        i_cos, i_sin = cyclic_time(predictions_24.iloc[:,i])
        cos_vals.append(i_cos)
        sin_vals.append(i_sin)

    cos_vals = np.mean(cos_vals, axis=0)
    sin_vals = np.mean(sin_vals, axis=0)

    ct_vals = np.concatenate((np.asarray(cos_vals).reshape(-1, 1), np.asarray(sin_vals).reshape(-1, 1)), axis=1)
    ct_24 = time24(ct_vals)
    return ct_24

# %%
# Get 24 hour CT predictions for each model
all_preds = []
for i in range(0, 10):
    i_preds = time24(results_dict[i])
    all_preds.append(i_preds)
# Create dataframe for results
all_preds = pd.DataFrame(data=all_preds, columns=X_test.columns).T
all_preds.head()

# %%
# Use circular_mean function to obtain an aggregated prediction across the sub-predictors
circ_pred = circular_mean(all_preds)

# Get error metrics for CT preditions
final_results = pd.DataFrame(data=Y_test.iloc[:,0].to_numpy() % 24, index=Y_test.index, columns=['Sampling time (hr)'])
final_results['Predicted CT (hr)'] = circ_pred
final_results['Error (mins)'] = errors(np.asarray(circ_pred), Y_test.iloc[:,0])
final_results['Absolute error (mins)'] = np.absolute(final_results['Error (mins)'])
final_results.head()

# %% [markdown]
# Based on cross-validation results, we expect a larger ensemble of sub-predictors will give more accurate results.
